# %% [markdown]
# <a href="https://colab.research.google.com/github/MoharanaSudhanshu/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MoharanaSudhanshu/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# # My Lane: Google Search Ranking & Discoverability
#
# I chose the Google Search Ranking & Discoverability lane because it focuses on identifying webpages that are likely to lose search performance. Predicting pages at risk allows SEO teams to prioritize optimization efforts before rankings and traffic decline. This combines data analysis and machine learning to support practical business decisions instead of relying on guesswork.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# ## Research Question
#
# Can historical search-performance metrics be used to identify webpages that are likely to experience declining search performance?
#
# ### Decision
# Which webpages should be prioritized for optimization?
#
# ### Action
# The SEO team reviews and updates the predicted at-risk pages to improve their visibility.
#
# ### Cost of a Wrong Call
# A false positive wastes time optimizing a healthy page. A false negative means a declining page is ignored, potentially resulting in lower rankings, reduced organic traffic, and missed business opportunities.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/MoharanaSudhanshu/flyrank-ml-internship.git
# %cd flyrank-ml-internship
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 123 (delta 40), reused 94 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 1.85 MiB | 13.72 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
# /content/flyrank-ml-internship

# %%
import os

print(os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# True

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 3))
print("Average Position:", round(df["avg_position"].mean(), 2))
# Out:
# Rows: 30000
# Average CTR: 0.511
# Average Position: 16.34

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This work provides decision support based on observed historical search-performance data. It may identify patterns associated with declining performance, but it cannot prove that any factor directly causes changes in Google's ranking algorithm. The model should be used to prioritize investigation rather than to make absolute predictions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
